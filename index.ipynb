# %% [markdown]
# # Principal Component Analysis in scikit-learn - Lab
#
# ## Introduction
#
# Now that you've seen a brief introduction to PCA, it's time to use scikit-learn to run PCA on your own.
#
# ## Objectives
#
# In this lab you will:
#
# - Implement PCA using the scikit-learn library
# - Determine the optimal number of n components when performing PCA by observing the explained variance
# - Plot the decision boundary of classification experiments to visually inspect their performance

# %% [markdown]
# ## Iris dataset
#
# To practice PCA, you'll take a look at the iris dataset. Run the cell below to load it..

# %%
from sklearn import datasets
import pandas as pd
 
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['Target'] = iris.get('target')
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# Before performing PCA and visualizing the principal components, it's helpful to get a little more context regarding the data that you'll be working with. Run the cell below in order to visualize the pairwise feature plots. With this, notice how the target labels are easily separable by any one of the given features.

# %%
pip install --upgrade matplotlib seaborn
# Out:
# Requirement already up-to-date: matplotlib in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (3.7.5)
# Requirement already up-to-date: seaborn in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (0.13.2)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (20.4)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied, skipping upgrade: importlib-resources>=3.2.0; python_version < "3.10" in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied, skipping upgrade: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (8.0.0)
# Requirement already satisfied, skipping upgrade: numpy<2,>=1.20 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (1.22.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied, skipping upgrade: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied, skipping upgrade: pandas>=1.2 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied, skipping upgrade: six in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from packaging>=20.0->matplotlib) (1.15.0)
# Requirement already satisfied, skipping upgrade: zipp>=3.1.0; python_version < "3.10" in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.3.0)
# Requirement already satisfied, skipping upgrade: tzdata>=2022.1 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from pandas>=1.2->seaborn) (2020.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

pd.plotting.scatter_matrix(df, figsize=(10,10));

# %% [markdown]
# - Assign all columns in the following `features` list to `X`
# - Assign the `'Target'` column to `y`

# %%
# Create features and target datasets
features = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
X = df[features]
y = df['Target']

# %% [markdown]
# Standardize all the columns in `X` using `StandardScaler`.

# %%
# Import StandardScaler
from sklearn.preprocessing import StandardScaler

# Standardize the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Preview X
pd.DataFrame(data=X, columns=features).head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444

# %% [markdown]
# ## PCA Projection to 2-D Space
#
# Now its time to perform PCA! Project the original data which is 4 dimensional into 2 dimensions. The new components are just the two main dimensions of variance present in the data.
#
# - Initialize an instance of PCA from scikit-learn with two components
# - Fit the data to the model
# - Extract the first two principal components from the trained model

# %%
# Import PCA
from sklearn.decomposition import PCA

# Instantiate PCA
pca = PCA(n_components=2,random_state=42)

# Fit PCA
principalComponents = pca.fit_transform(X)

# %% [markdown]
# To visualize the components, it will be useful to also look at the target associated with the particular observation.
# As such, append the target (flower type) to the principal components in a pandas dataframe.

# %%
# Create a new dataset from principal components 
principalComponents_df = pd.DataFrame(principalComponents,columns=['pc1','pc2'])
principalComponents_df['flower_type']=y
principalComponents_df
# Out:
#           pc1       pc2  flower_type
# 0   -2.264703  0.480027            0
# 1   -2.080961 -0.674134            0
# 2   -2.364229 -0.341908            0
# 3   -2.299384 -0.597395            0
# 4   -2.389842  0.646835            0
# ..        ...       ...          ...
# 145  1.870503  0.386966            2
# 146  1.564580 -0.896687            2
# 147  1.521170  0.269069            2
# 148  1.372788  1.011254            2
# 149  0.960656 -0.024332            2
#
# [150 rows x 3 columns]

# %% [markdown]
# Great, you now have a set of two dimensions, reduced from four against our target variable, the flower type.

# %% [markdown]
# ## Visualize Principal Components

# %% [markdown]
# Using the target data, we can visualize the principal components according to the class distribution.
# - Create a scatter plot from principal components while color coding the examples according to what flower type each example is classified as

# %%
import matplotlib.pyplot as plt
# Principal Components scatter plot
plt.figure(figsize=(8,6))
scatter = plt.scatter(principalComponents_df.iloc[:,0],principalComponents_df.iloc[:,1],c=principalComponents_df['flower_type'],cmap='coolwarm',s=60)
# Your code here 
plt.xlabel('principal component 1')
plt.ylabel("principal component 2")
plt.colorbar(label = 'Flower type')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Explained Variance
#
#
# You can see above that the three classes in the dataset are fairly well separable. As such, this compressed representation of the data is probably sufficient for the classification task at hand. Compare the variance in the overall dataset to what was captured from your two primary components.

# %%
# Calculate the variance explained by principal components
import numpy as np
print('Variance of each component:', pca.explained_variance_ratio_)
print('\n Total Variance Explained:', np.cumsum(pca.explained_variance_ratio_))
# Out:
# Variance of each component: [0.72962445 0.22850762]
#
#  Total Variance Explained: [0.72962445 0.95813207]

# %% [markdown]
# As you should see, these first two principal components account for the vast majority of the overall variance in the dataset. This is indicative of the total information encapsulated in the compressed representation compared to the original encoding.

# %% [markdown]
# ## Compare Performance of a Classifier with PCA
#
# Since the principal components explain 95% of the variance in the data, it is interesting to consider how a classifier trained on the compressed version would compare to one trained on the original dataset.
#
# - Run a `KNeighborsClassifier` to classify the Iris dataset
# - Use a train/test split of 80/20
# - For the reproducibility of results, set `random_state=9` for the split
# - Time the process for splitting, training and making predictions

# %%
# Classification - complete Iris dataset
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=9)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Your code here 
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train_scaled,y_train)
y_pred = knn.predict(X_test_scaled)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 1.0

# %% [markdown]
# Great, so you can see that we are able to classify the data with 100% accuracy in the given time. Remember the time taken may be different based on the load on your CPU and number of processes running on your machine.
#
# Now repeat the above process for the dataset made from principal components:
#
# - Run a `KNeighborsClassifier` to classify the Iris dataset with principal components
# - Use a train/test split of 80/20
# - For the reproducibility of results, set `random_state=9` for the split
# - Time the process for splitting, training and making predictions

# %%
# Classification - reduced (PCA) Iris dataset

pca2 = PCA(n_components=2,random_state=9)
X_train_p = pca2.fit_transform(X_train_scaled)
X_test_p = pca2.transform(X_test_scaled)
# Your code here 
knn2 = KNeighborsClassifier(n_neighbors=10)
knn2.fit(X_train_p,y_train)
y_pred_p = knn2.predict(X_test_p)
acc2 = accuracy_score(y_test,y_pred_p)
acc2
# Out:
# 0.9666666666666667

# %% [markdown]
# Although some accuracy is lost in this representation of the data, we were able to use half of the number of features to train the model!
#
# In more complex cases, PCA can even improve the accuracy of some machine learning tasks. In particular, PCA can be useful to reduce overfitting.

# %% [markdown]
# ## Visualize the Learned Decision Boundary
#
# Run the cell below to visualize the decision boundary learned by the k-nearest neighbor classification model trained using the principal components of the data..

# %%
# Plot decision boundary using principal components 
import numpy as np 
def decision_boundary(pred_func):
    
    # Set the boundary
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    h = 0.01
    
    # Build meshgrid
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Plot the contour
    plt.figure(figsize=(15,10))
    plt.contourf(xx, yy, Z, cmap=plt.cm.afmhot)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral, marker='x')

decision_boundary(lambda x: knn2.predict(x))

plt.title('decision boundary');

# %% [markdown]
# ## Summary
#
# In this lab, you applied PCA to the popular Iris dataset. You looked at the performance of a simple classifier and the impact of PCA on the accuracy of the model and the time it took to run the model. From here, you'll continue to explore PCA at more fundamental levels.
